# %% [markdown]
# <div class="alert alert-info" style="background-color:#001b79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'> DECISION TREE RANDOM FOREST </h2>
# </div>

# %% [markdown]
# ### 1. Decision Tree
#
#    - Is a tree like structure in which internal node represents test on an attribute
#
#    - Here input is not discrete or continous value, its categorial/Classification values and o/p is labelled or categorial, then we use Decision tree
#
#    - DT is based on some conditions
#
# ### 2. Random Forest
#
#    - Its a Ensemble Technique :
#             Means many same type algorithm (DT) are used to build, so its called as ENSEMBLE Teqnique
#
#    - Its combination of many Decision tree, every DT o/p will be considered and majority will be the final o/p
#
#    - Each DT uses different combination of conditions in each node and final o/p is decided.
#
#    - It’s a mutiple Dtand merged them together to get more accurate result
#
#    - RF alsways gives very good precision
#
#    - here n_estimators will be the no of DT in the model
#
#    - n_estimator:number of trees in the forest.
#
#
#
# ### 3. Gradient Boosted Decison Trees (GBDT) :
#
#    - Its same as random forest, it ensembles samples of multiple trees to create powerful prediction for classification and regression problem.
#
#
#    - Learning Rate:
#
#    - This is one of the parameter in GBDT
#
#    - More learning rate, will build more complex model with high accuracy but becomes like overfit, Low learning rate will build simple model with little les accuracy.

# %% [markdown]
# <div class="alert alert-info" style="background-color:#001b32; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>Problem  Statement </h2>
# </div>

# %% [markdown]
# # Module 7–Supervised Learning -1

# %% [markdown]
# ## Case Study
#     Objective:
#         •Learn to handle missing values
#         •Learn to fit a decision tree and compare its accuracy with random forest classifier.

# %% [markdown]
# ### 1.Let’s attempt to predict the survival of a horse based on various observed medical conditions.
#     Load the data from ‘horses.csv’ and observe whether it contains missing values.
#
#     [Hint: Pandas dataframe has a method isnull]
#
#     Here "Outcome" is the output column, it has more than 2 value, so we cant use Logistic Regression and its not continous value. so we cant use Linear or polynomial Regression. So we are with DT, RF, Naive bayes , SVM etc

# %% [markdown]
#     Attribute Information:
#
#     1: surgery?
#     1 = Yes, it had surgery
#     2 = It was treated without surgery
#
#     2: Age
#     1 = Adult horse
#     2 = Young (< 6 months)
#
#     3: Hospital Number
#     - numeric id
#     - the case number assigned to the horse (may not be unique if the horse is treated > 1 time)
#
#     4: rectal temperature
#     - linear
#     - in degrees celsius.
#     - An elevated temp may occur due to infection.
#     - temperature may be reduced when the animal is in late shock
#     - normal temp is 37.8
#     - this parameter will usually change as the problem progresses, eg. may start out normal, then become elevated because of the lesion, passing back through the normal range as the horse goes into shock
#     5: pulse
#     - linear
#     - the heart rate in beats per minute
#     - is a reflection of the heart condition: 30 -40 is normal for adults
#     - rare to have a lower than normal rate although athletic horses may have a rate of 20-25
#     - animals with painful lesions or suffering from circulatory shock may have an elevated heart rate
#
#     6: respiratory rate
#     - linear
#     - normal rate is 8 to 10
#     - usefulness is doubtful due to the great fluctuations
#
#     7: temperature of extremities
#     - a subjective indication of peripheral circulation
#     - possible values:
#     1 = Normal
#     2 = Warm
#     3 = Cool
#     4 = Cold
#     - cool to cold extremities indicate possible shock
#     - hot extremities should correlate with an elevated rectal temp.
#
#     8: peripheral pulse
#     - subjective
#     - possible values are:
#     1 = normal
#     2 = increased
#     3 = reduced
#     4 = absent
#     - normal or increased p.p. are indicative of adequate circulation while reduced or absent indicate poor perfusion
#
#     9: mucous membranes
#     - a subjective measurement of colour
#     - possible values are:
#     1 = normal pink
#     2 = bright pink
#     3 = pale pink
#     4 = pale cyanotic
#     5 = bright red / injected
#     6 = dark cyanotic
#     - 1 and 2 probably indicate a normal or slightly increased circulation
#     - 3 may occur in early shock
#     - 4 and 6 are indicative of serious circulatory compromise
#     - 5 is more indicative of a septicemia
#
#     10: capillary refill time
#     - a clinical judgement. The longer the refill, the poorer the circulation
#     - possible values
#     1 = < 3 seconds
#     2 = >= 3 seconds
#
#     11: pain - a subjective judgement of the horse's pain level
#     - possible values:
#     1 = alert, no pain
#     2 = depressed
#     3 = intermittent mild pain
#     4 = intermittent severe pain
#     5 = continuous severe pain
#     - should NOT be treated as a ordered or discrete variable!
#     - In general, the more painful, the more likely it is to require surgery
#     - prior treatment of pain may mask the pain level to some extent
#
#     12: peristalsis
#     - an indication of the activity in the horse's gut. As the gut becomes more distended or the horse becomes more toxic, the activity decreases
#     - possible values:
#     1 = hypermotile
#     2 = normal
#     3 = hypomotile
#     4 = absent
#
#     13: abdominal distension
#     - An IMPORTANT parameter.
#     - possible values
#     1 = none
#     2 = slight
#     3 = moderate
#     4 = severe
#     - an animal with abdominal distension is likely to be painful and have reduced gut motility.
#     - a horse with severe abdominal distension is likely to require surgery just tio relieve the pressure
#
#     14: nasogastric tube
#     - this refers to any gas coming out of the tube
#     - possible values:
#     1 = none
#     2 = slight
#     3 = significant
#     - a large gas cap in the stomach is likely to give the horse discomfort
#
#     15: nasogastric reflux
#     - possible values
#     1 = none
#     2 = > 1 liter
#     3 = < 1 liter
#     - the greater amount of reflux, the more likelihood that there is some serious obstruction to the fluid passage from the rest of the intestine
#
#     16: nasogastric reflux PH
#     - linear
#     - scale is from 0 to 14 with 7 being neutral
#     - normal values are in the 3 to 4 range
#
#     17: rectal examination - feces
#     - possible values
#     1 = normal
#     2 = increased
#     3 = decreased
#     4 = absent
#     - absent feces probably indicates an obstruction
#
#     18: abdomen
#     - possible values
#     1 = normal
#     2 = other
#     3 = firm feces in the large intestine
#     4 = distended small intestine
#     5 = distended large intestine
#     - 3 is probably an obstruction caused by a mechanical impaction and is normally treated medically
#     - 4 and 5 indicate a surgical lesion
#
#     19: packed cell volume
#     - linear
#     - the # of red cells by volume in the blood
#     - normal range is 30 to 50. The level rises as the circulation becomes compromised or as the animal becomes dehydrated.
#
#     20: total protein
#     - linear
#     - normal values lie in the 6-7.5 (gms/dL) range
#     - the higher the value the greater the dehydration
#
#     21: abdominocentesis appearance
#     - a needle is put in the horse's abdomen and fluid is obtained from
#     the abdominal cavity
#     - possible values:
#     1 = clear
#     2 = cloudy
#     3 = serosanguinous
#     - normal fluid is clear while cloudy or serosanguinous indicates a compromised gut
#
#     22: abdomcentesis total protein
#     - linear
#     - the higher the level of protein the more likely it is to have a compromised gut. Values are in gms/dL
#
#     23: outcome
#     - what eventually happened to the horse?
#     - possible values:
#     1 = lived
#     2 = died
#     3 = was euthanized
#
#     24: surgical lesion?
#     - retrospectively, was the problem (lesion) surgical?
#     - all cases are either operated upon or autopsied so that this value and the lesion type are always known
#     - possible values:
#     1 = Yes
#     2 = No
#
#     25, 26, 27: type of lesion
#     - first number is site of lesion
#     1 = gastric
#     2 = sm intestine
#     3 = lg colon
#     4 = lg colon and cecum
#     5 = cecum
#     6 = transverse colon
#     7 = retum/descending colon
#     8 = uterus
#     9 = bladder
#     11 = all intestinal sites
#     00 = none
#     - second number is type
#     1 = simple
#     2 = strangulation
#     3 = inflammation
#     4 = other
#     - third number is subtype
#     1 = mechanical
#     2 = paralytic
#     0 = n/a
#     - fourth number is specific code
#     1 = obturation
#     2 = intrinsic
#     3 = extrinsic
#     4 = adynamic
#     5 = volvulus/torsion
#     6 = intussuption
#     7 = thromboembolic
#     8 = hernia
#     9 = lipoma/slenic incarceration
#     10 = displacement
#     0 = n/a
#     28: cp_data
#     - is pathology data present for this case?
#     1 = Yes
#     2 = No
#     - this variable is of no significance since pathology data is not included or collected for these cases

# %% [markdown]
# ##  1. Import all Librariy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import metrics

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.metrics import roc_curve
from sklearn.metrics import auc

horse_df = pd.read_csv(r"..\Dataset\horse.csv")
horse_df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %% [markdown]
# ## 2. Data Exploration with Graphs and Visualization

# %%
horse_df.describe()
# Out:
#        hospital_number  rectal_temp       pulse  respiratory_rate  \
# count     2.990000e+02   239.000000  275.000000        241.000000
# mean      1.087733e+06    38.168619   72.000000         30.460581
# std       1.532032e+06     0.733744   28.646219         17.666102
# min       5.184760e+05    35.400000   30.000000          8.000000
# 25%       5.289040e+05    37.800000   48.000000         18.000000
# 50%       5.303010e+05    38.200000   64.000000         25.000000
# 75%       5.347360e+05    38.500000   88.000000         36.000000
# max       5.305629e+06    40.800000  184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count              53.000000          270.000000     266.000000
# mean                4.707547           46.307407      24.274436
# std                 1.982311           10.436743      27.364194
# min                 1.000000           23.000000       3.300000
# ...

# %%
horse_df.info()
# By this we can see which are all integer/Float and which are all categorial/Object value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
# surgery                  299 non-null object
# age                      299 non-null object
# hospital_number          299 non-null int64
# rectal_temp              239 non-null float64
# pulse                    275 non-null float64
# respiratory_rate         241 non-null float64
# temp_of_extremities      243 non-null object
# peripheral_pulse         230 non-null object
# mucous_membrane          252 non-null object
# capillary_refill_time    267 non-null object
# pain                     244 non-null object
# peristalsis              255 non-null object
# abdominal_distention     243 non-null object
# nasogastric_tube         195 non-null object
# nasogastric_reflux       193 non-null object
# nasogastric_reflux_ph    53 non-null float64
# rectal_exam_feces        197 non-null object
# abdomen                  181 non-null object
# ...

# %%
# Here "Outcome" is op column so remove this from main dataset and apply label encoder to this. Because it has categorial value
target = horse_df['outcome']
target.unique()
#Here we can see 3, values, this will be converted to integer by label encoder later
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
#Drop the op field
horse_df =horse_df.drop(['outcome'],axis=1)

# %%
horse_df.columns
# Out:
# Index(['surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse',
#        'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen',
#        'packed_cell_volume', 'total_protein', 'abdomo_appearance',
#        'abdomo_protein', 'surgical_lesion', 'lesion_1', 'lesion_2', 'lesion_3',
#        'cp_data'],
#       dtype='object')

# %% [markdown]
# ### 2.1   This dataset contains many categorical features, replace them with label encoding.
#         [Hint: Refer to get_dummies methods in pandas dataframe or Label encoder in scikit-learn]

# %%
# select Categorial fields in dataframe
print(horse_df.select_dtypes(include = ['category', 'object']).head())

# Here select_dtypes provides all Column with categorial value
cat_features = horse_df.select_dtypes(include = ['category', 'object']).columns
cat_features
# Out:
#   surgery    age temp_of_extremities peripheral_pulse mucous_membrane  \
# 0      no  adult                cool          reduced             NaN
# 1     yes  adult                 NaN              NaN   pale_cyanotic
# 2      no  adult              normal           normal       pale_pink
# 3     yes  young                cold           normal   dark_cyanotic
# 4      no  adult                 NaN              NaN   dark_cyanotic
#
#   capillary_refill_time          pain peristalsis abdominal_distention  \
# 0            more_3_sec  extreme_pain      absent               severe
# 1            less_3_sec     mild_pain      absent               slight
# 2            less_3_sec     mild_pain  hypomotile                 none
# 3            more_3_sec     depressed      absent               severe
# 4            more_3_sec           NaN         NaN                  NaN
#
#   nasogastric_tube nasogastric_reflux rectal_exam_feces        abdomen  \
# ...

# %%
"""category_variables = ['surgery', 'age', 'temp_of_extremities','peripheral_pulse',
       'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
       'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux', 'rectal_exam_feces', 'abdomen',
      'abdomo_appearance', 'surgical_lesion','cp_data']
"""
print(horse_df.head())
#Here USe one hot dog and replace vaues in DF directly, 
#here same col values will be repaced from "categorial"(yes/no etc) value to 0 or 1, 
#if req new col will be added based on no of unique value in col
for category in cat_features:
    horse_df[category] = pd.get_dummies(horse_df[category])

horse_df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %%
#Another way of assign one hot dog without for loop . here no of column will be more. ye/no value will have 2 
# new column as col_yes, col_no, In previous for loop it will be same on old column only

#new_df = pd.get_dummies(horse_df[cat_features] )
####pd.get_dummies(horse_df[cat_features] ), dummy_na = True)
#new_df.head()

## Remove categorial fields/col and add newly created one hot dog applied categorila fields to main df
## remove col
#horse_df1 = horse_df.drop(horse_df[cat_features] , axis =1 )
#horse_df1.head()

## append col
#horse_hd_df = pd.concat([horse_df1, new_df], axis=1)
#horse_hd_df.head()

# %% [markdown]
# ### 3.2  Replace the missing values by the most frequent value in each column.
#         [Hint: Refer to Imputer class in Scikit learn preprocessing module]

# %%
# to find in Dtaframe for all fields, we can do like below. it gives col wise sum of null values
horse_df.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities        0
# peripheral_pulse           0
# mucous_membrane            0
# capillary_refill_time      0
# pain                       0
# peristalsis                0
# abdominal_distention       0
# nasogastric_tube           0
# nasogastric_reflux         0
# nasogastric_reflux_ph    246
# rectal_exam_feces          0
# abdomen                    0
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance          0
# abdomo_protein           198
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
"""
below list of col has NULL Values

rectal_temp               60
pulse                     24
respiratory_rate          58
temp_of_extremities       56
peripheral_pulse          69
mucous_membrane           47
capillary_refill_time     32
pain                      55
peristalsis               44
abdominal_distention      56
nasogastric_tube         104
nasogastric_reflux       106
nasogastric_reflux_ph    246
rectal_exam_feces        102
abdomen                  118
packed_cell_volume        29
total_protein             33
abdomo_appearance        165
abdomo_protein           198

"""
# Out:
# '\nbelow list of col has NULL Values\n\nrectal_temp               60\npulse                     24\nrespiratory_rate          58\ntemp_of_extremities       56\nperipheral_pulse          69\nmucous_membrane           47\ncapillary_refill_time     32\npain                      55\nperistalsis               44\nabdominal_distention      56\nnasogastric_tube         104\nnasogastric_reflux       106\nnasogastric_reflux_ph    246\nrectal_exam_feces        102\nabdomen                  118\npacked_cell_volume        29\ntotal_protein             33\nabdomo_appearance        165\nabdomo_protein           198\n\n'

# %%
# 1 Use Simple imputer

"""
#Not sure how to use, so followed another method
from sklearn.impute import SimpleImputer
imp = SimpleImputer( strategy='most_frequent')
#imp.fit(horse_hd_df)  
print(imp.fit_transform(horse_hd_df)  )
#horse_hd_df = imp.fit_transform(horse_hd_df)
##Edu way
"""
## Convert to null to most freq value by using imputer
"""

from sklearn.preprocessing import Imputer
imp = Imputer(missing_values="NaN",strategy="most_frequent",axis =0)
X_train = imp.fit_transform(X_train)
X_test = imp.fit_transform(X_test)
X_test[:2]
"""
# Out:
# '\n\nfrom sklearn.preprocessing import Imputer\nimp = Imputer(missing_values="NaN",strategy="most_frequent",axis =0)\nX_train = imp.fit_transform(X_train)\nX_test = imp.fit_transform(X_test)\nX_test[:2]\n'

# %%
# 2 Simple imputer didnt work, so used fillna function to fill commonly occured value by 'MODE' function

print("Total null values: " , horse_df.isnull().sum().sum())


#Here mode will fill with frequently occured value in each col

horse_df = horse_df.fillna(horse_df.mode().iloc[0])


print("\n Total null values after mode func: " , horse_df.isnull().sum().sum())
#horse_hd_df.mode().iloc[0]
# Out:
# Total null values:  648
#
#  Total null values after mode func:  0

# %%
horse_df.head()
# Out:
#    surgery  age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        1    1           530101         38.5   66.0              28.0
# 1        0    1           534817         39.2   88.0              20.0
# 2        1    1           530334         38.3   40.0              24.0
# 3        0    0          5290409         39.1  164.0              84.0
# 4        1    1           530255         37.3  104.0              35.0
#
#    temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0                    0                 0                0
# 1                    0                 0                0
# 2                    0                 0                0
# 3                    1                 0                0
# 4                    0                 0                0
#
#    capillary_refill_time   ...     abdomen  packed_cell_volume  total_protein  \
# 0                      0   ...           1                45.0            8.4
# ...

# %% [markdown]
# ## 3 Building Machine Learning Logistic Models

# %% [markdown]
# ### 3.1.Fit a DECISION TREE classifier and observe the accuracy.

# %%
# these 3 are o/p column, so we exclude this from i/p varibles
#outcome_died , outcome_euthanized ,outcome_lived
from sklearn.preprocessing import LabelEncoder


X, Y = horse_df.values,target.values

print("Before apply label encoder: " , Y[0:5])

# Here label encoder used to convert category to numeric value

label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print("\n After apply label encoder: " , Y[0:5])
# Out:
# Before apply label encoder:  ['died' 'euthanized' 'lived' 'died' 'died']
#
#  After apply label encoder:  [0 1 2 0 0]

# %% [markdown]
# #### Spliting data

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(X,Y, test_size=.30, random_state = 5)

# %%
# DecisionTreeClassifier Applied
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

model = DecisionTreeClassifier()
model.fit(train_X, train_Y)
prediction_op = model.predict(test_X)
metrics.accuracy_score(test_Y, prediction_op)

#Decision tree classifier provides approx 64% accuracy
# Out:
# 0.6333333333333333

# %% [markdown]
# #### 3.1.1.Here Visualize DECISION TREE classifier ( With only 1 Tree)

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(443.6404733009708, 525.48, 'X[18] <= 50.5\ngini = 0.565\nsamples = 209\nvalue = [56, 31, 122]'),
#  Text(155.92172330097085, 489.24, 'X[23] <= 2112.5\ngini = 0.456\nsamples = 162\nvalue = [32, 16, 114]'),
#  Text(32.50485436893204, 453.0, 'X[15] <= 1.75\ngini = 0.081\nsamples = 47\nvalue = [2, 0, 45]'),
#  Text(16.25242718446602, 416.76, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(48.75728155339806, 416.76, 'X[15] <= 6.1\ngini = 0.043\nsamples = 46\nvalue = [1, 0, 45]'),
#  Text(32.50485436893204, 380.52, 'gini = 0.0\nsamples = 45\nvalue = [0, 0, 45]'),
#  Text(65.00970873786407, 380.52, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(279.3385922330097, 453.0, 'X[3] <= 38.15\ngini = 0.553\nsamples = 115\nvalue = [30, 16, 69]'),
#  Text(156.42961165048544, 416.76, 'X[2] <= 527707.5\ngini = 0.631\nsamples = 68\nvalue = [22, 14, 32]'),
#  Text(97.51456310679612, 380.52, 'X[12] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0]'),
# ...

# %% [markdown]
# ### 3.2 Fit a RANDOM FOREST classifier and observe the accuracy.

# %%
# RandomForestClassifier Applied
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(train_X, train_Y)
prediction_op_rf = model_rf.predict(test_X)
metrics.accuracy_score(test_Y, prediction_op_rf)

#Random forest classifier provides approx 67% accuracy, its more than decision tree
# Out:
# 0.7222222222222222

# %% [markdown]
# #### 3.21.1.Here Visualize Random forest individual  DT with n_estimator ( With only 1 Tree)

# %%
len(model_rf.estimators_)
# This provides count of no of DT
# Out:
# 100

# %%
plt.figure(figsize=(15,10))
print(tree.export_text(model_rf.estimators_[0]))
tree.plot_tree(model_rf.estimators_[0],filled=True)
# This shows 1st DT
# Out:
# |--- feature_18 <= 50.50
# |   |--- feature_0 <= 0.50
# |   |   |--- feature_3 <= 37.15
# |   |   |   |--- feature_21 <= 2.60
# |   |   |   |   |--- class: 2.0
# |   |   |   |--- feature_21 >  2.60
# |   |   |   |   |--- class: 0.0
# |   |   |--- feature_3 >  37.15
# |   |   |   |--- feature_15 <= 3.25
# |   |   |   |   |--- feature_5 <= 82.00
# |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_25 <= 1104.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 528594.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  528594.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 529407.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  529407.50
# ...

# %%
# This should plot all 100 DT, But we cant get all tree diagram, only 1 we will get by this loop, so we printed the text
plt.figure(figsize=(15,10))
for i in range(len(model_rf.estimators_)):
    #tree.plot_tree(model_rf.estimators_[1],filled=True)
    print(" \n \n This is DT no: ", i)
    print(tree.export_text(model_rf.estimators_[0]))
# Out:
#
#
#  This is DT no:  0
# |--- feature_18 <= 50.50
# |   |--- feature_0 <= 0.50
# |   |   |--- feature_3 <= 37.15
# |   |   |   |--- feature_21 <= 2.60
# |   |   |   |   |--- class: 2.0
# |   |   |   |--- feature_21 >  2.60
# |   |   |   |   |--- class: 0.0
# |   |   |--- feature_3 >  37.15
# |   |   |   |--- feature_15 <= 3.25
# |   |   |   |   |--- feature_5 <= 82.00
# |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_25 <= 1104.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 528594.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  528594.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 529407.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  529407.50
# ...

# %% [markdown]
# # 4. Model Evaluation

# %% [markdown]
# ## 4.1. Model Evaluation -Accuracy Score

# %%
print("Decision Tree Accuracy :" ,metrics.accuracy_score(test_Y, prediction_op))
print("Random Forest Accuracy :" ,metrics.accuracy_score(test_Y, prediction_op_rf))
# Out:
# Decision Tree Accuracy : 0.7
# Random Forest Accuracy : 0.7333333333333333

# %% [markdown]
# > Accuracy wise  Random forest IS best value

# %% [markdown]
# ## 4.2. Model Evaluation - confusion_matrix

# %%
print("Decision Tree confusion_matrix :\n" ,confusion_matrix(test_Y, prediction_op))
print("Random Forest confusion_matrix :\n" ,confusion_matrix(test_Y, prediction_op_rf))
# Out:
# Decision Tree confusion_matrix :
#  [[19  1  1]
#  [ 2  6  5]
#  [10  8 38]]
# Random Forest confusion_matrix :
#  [[13  2  6]
#  [ 3  2  8]
#  [ 5  0 51]]

# %% [markdown]
# ## 4.3. Model Evaluation - classification_report

# %%
print("Decision Tree classification_report :" ,classification_report(test_Y, prediction_op))
print("Random Forest classification_report :" ,classification_report(test_Y, prediction_op_rf))
# Out:
# Decision Tree classification_report :               precision    recall  f1-score   support
#
#            0       0.61      0.90      0.73        21
#            1       0.40      0.46      0.43        13
#            2       0.86      0.68      0.76        56
#
#    micro avg       0.70      0.70      0.70        90
#    macro avg       0.63      0.68      0.64        90
# weighted avg       0.74      0.70      0.71        90
#
# Random Forest classification_report :               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        21
#            1       0.50      0.15      0.24        13
#            2       0.78      0.91      0.84        56
#
#    micro avg       0.73      0.73      0.73        90
#    macro avg       0.63      0.56      0.57        90
# weighted avg       0.70      0.73      0.70        90

# %% [markdown]
# ## 4.4. Model Evaluation - ROC AUC

# %%
#### Here output is not a binary. so ROC not applied. its little complex

# %% [markdown]
# # 5. CONCLUSION

# %% [markdown]
# ## Conclusion : Random forest classifier provides approx 72% accuracy, its more than decision tree 64%
