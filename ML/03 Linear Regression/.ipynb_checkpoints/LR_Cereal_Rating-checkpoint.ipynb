# %% [markdown]
# <div class="alert alert-info" style="background-color:#001b79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'> Linear Regression </h2>
# </div>

# %% [markdown]
# ### Linear regression
#
# - Linear regression analysus is a powerful technique used for predicting unknown value of a variable(Dependent variable) from the known values of another variables(Independent variable)
# - Here output value is continous and numerical value
# - It is used to show the linear relationship between a dependent variable and one or more independent variables.
#
# ### Regression Line:
# - Regression line is simply a single line that best fits the data(in terms of having smallest overall distance from the line to the points)
# - This technique is used for finding the "best fitting line" using the "Least squares method"

# %% [markdown]
# <div class="alert alert-info" style="background-color:#001b32; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>Problem  Statement </h2>
# </div>

# %% [markdown]
# # Module 6
#     Case Study
#     Objectives:1.
#             Provide the learner some more practice forexploratory data analysis.
#             2.Equip the learner to fit and evaluate a linear regression model.

# %% [markdown]
# ## Questions:
#     1.Load the data from “cereal.csv” and plot histograms of sugar and vitamin content across different cereals.
#     [Hint: Extract values of a specific column using their labels and use hist method of pyplot]

# %% [markdown]
# ## 1. Import all Librariy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cerel_df = pd.read_csv(r"..\Dataset\cereal.csv")
cerel_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ## 2. Data Exploration with Graphs and Visualization

# %%
#plot histograms of sugar and vitamin content across different cereals.

plt.figure()
plt.hist(cerel_df['sugars'])
plt.title('Sugars')

plt.show()
#many cerels have sugur range 2 to 4

# %%
#plot histograms of sugar and vitamin content across different cereals.

plt.figure()
plt.hist(cerel_df['vitamins'])
plt.title('Vitamins')

plt.show()

# %% [markdown]
# ## 3. Feature scaling

# %% [markdown]
# ## 2. The names of the manufactures are coded using alphabets, create a new column with their fullname using the below mapping.
#
#     'N': 'Nabisco',
#     'Q': 'Quaker Oats',
#     'K': 'Kelloggs',
#     'R': 'Raslston Purina',
#     'G': 'General Mills' ,
#     'P' :'Post' ,
#     'A':'American Home Foods Products'
#
#      Create a bar plot where each manufacturer is on the y axis and the height of the bars depict the number of cereals manufactured by them.
#
#      [Hint: Try using countplot this time or bar method of pyplot]

# %%
#Method 1: Using map function

values_dict = {'N': 'Nabisco', 'Q': 'Quaker Oats', 'K': 'Kelloggs', 'R': 'Raslston Purina', 'G': 'General Mills' , 'P' :'Post' , 'A':'American Home Foods Products'}
cerel_df['Fullname'] = cerel_df['mfr'].map(values_dict)
cerel_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#           Fullname
# 0          Nabisco
# 1      Quaker Oats
# 2         Kelloggs
# ...

# %%
#Method 2 lengthy way
cerel_df["Fullname"] = cerel_df["mfr"]

# %%
cerel_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating Fullname
# 0    5.0       6     280        25      3     1.0  0.33  68.402973        N
# 1    8.0       8     135         0      3     1.0  1.00  33.983679        Q
# 2    7.0       5     320        25      3     1.0  0.33  59.425505        K
# 3    8.0       0     330        25      3     1.0  0.50  93.704912        K
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843        R

# %%
#cerel_df.describe()
for i in range(77):
    if cerel_df.loc[i, "Fullname"] == 'N':
        cerel_df.loc[i, "Fullname"] = 'Nabisco'
    elif cerel_df.loc[i, "Fullname"] == 'Q':
        cerel_df.loc[i, "Fullname"] = 'Quaker Oats'
    elif cerel_df.loc[i, "Fullname"] == 'K':
        cerel_df.loc[i, "Fullname"] = 'Kelloggs'
    elif cerel_df.loc[i, "Fullname"] == 'R':
        cerel_df.loc[i, "Fullname"] = 'Raslston Purina'
    elif cerel_df.loc[i, "Fullname"] == 'G':
        cerel_df.loc[i, "Fullname"] = 'General Mills'
    elif cerel_df.loc[i, "Fullname"] == 'P':
        cerel_df.loc[i, "Fullname"] = 'Post'
    elif cerel_df.loc[i, "Fullname"] == 'A':
        cerel_df.loc[i, "Fullname"] = 'American Home Foods Products'

# %%
cerel_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#           Fullname
# 0          Nabisco
# 1      Quaker Oats
# 2         Kelloggs
# ...

# %%
#cOUNTPLOT
#Create a bar plot where each manufacturer is on the y axis and the height of the bars depict the number of cereals manufactured by them.
# This is not the one req, reverse of this
import seaborn as sn
x = cerel_df["Fullname"]
sn.countplot(x)

# %%
y = cerel_df["Fullname"]
sn.countplot(y=y )#, hue = 'type' , data=cerel_df , palette ='cool')
plt.show()
#Edu sol

# Here we need to assign to Y, else it will treat as x axis
#hue--> here we passed colname =type, based on this value barplot splitted with count

sn.countplot(y=y , hue = 'type' , data=cerel_df , palette ='cool')
plt.show()

# %% [markdown]
# # 4. Building Machine Learning Linear Models

# %% [markdown]
# ## 3. Extract the rating as your target variable ‘y’ and all numerical parameters as your predictors ‘x’.   Separate 25% of your data as test set.

# %%
print(cerel_df.head())
# target variable
y = cerel_df["rating"]

#predictors, take only numeric col
x = cerel_df.iloc[: , 3:15]
x.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#           Fullname
# 0          Nabisco
# 1      Quaker Oats
# 2         Kelloggs
# ...

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split( x, y, test_size = .25, random_state = 5)

# %%
print (train_x.shape)
print (test_x.shape)
# Out:
# (57, 12)
# (20, 12)

# %%
print(train_x.head())
print(train_y.head())
print(test_x.head())
print(test_y.head())
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 58       120        3    1     210    5.0   14.0      12     240        25
# 26       100        3    0       0    3.0   14.0       7     100        25
# 64        90        3    0       0    4.0   19.0       0     140         0
# 35       120        1    2     220    1.0   12.0      11      45        25
# 21       110        2    0     220    1.0   21.0       3      30        25
#
#     shelf  weight  cups
# 58      2    1.33  0.75
# 26      2    1.00  0.80
# 64      1    1.00  0.67
# 35      2    1.00  1.00
# 21      3    1.00  1.00
# 58    39.259197
# 26    58.345141
# 64    74.472949
# 35    21.871292
# 21    46.895644
# Name: rating, dtype: float64
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 40       110        2    1     260    0.0   21.0       3      40        25
# 25       110        1    0     200    1.0   14.0      11      25        25
# ...

# %% [markdown]
# ## 4. Fit a linear regression module and measure the mean squared error on test dataset.
#     [ Hint: Explore linear models and metrics section of sklearn documentation]

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
#Fit train data
lr.fit(train_x, train_y)

#Predict
y_pred = lr.predict(test_x)

data = {"Actual o/p" : test_y , "Pred O/p" :y_pred}
new_data = pd.DataFrame(data)
print("Both o/p :\n" ,new_data)

combined = zip(test_y,y_pred )
print(combined)# It shows as zip
# Out:
# Both o/p :
#      Actual o/p   Pred O/p
# 40   39.241114  39.241114
# 25   31.435973  31.435973
# 10   18.042851  18.042851
# 59   39.703400  39.703400
# 72   39.106174  39.106174
# 45   34.139765  34.139764
# 29   28.025765  28.025764
# 24   32.207582  32.207581
# 17   35.782791  35.782791
# 48   29.924285  29.924285
# 12   19.823573  19.823573
# 37   28.742414  28.742414
# 74   49.787445  49.787445
# 33   53.371007  53.371007
# 13   40.400208  40.400208
# 65   72.801787  72.801787
# 49   40.692320  40.692320
# 76   36.187559  36.187559
# 68   59.363993  59.363993
# 6    33.174094  33.174094
# ...

# %% [markdown]
# ## 5. Model Evaluation

# %%
#score
print(" Train Score: " ,lr.score(train_x,train_y))
print(" Test Score: " ,lr.score(test_x,test_y))
#both have very good score near to 100
# Out:
#  Train Score:  0.9999999999999997
#  Test Score:  0.999999999999999

# %%
# measure the mean squared error on test dataset

from sklearn import metrics

#Print Mean Absolute Error MAE
print("MAE :" , metrics.mean_absolute_error(test_y,y_pred))

#Print Mean Squared Error MSE
print("MSE :" , metrics.mean_squared_error(test_y,y_pred))

#Print Root Mean Squared Error RMSE
print("RMSE :" , np.sqrt(metrics.mean_squared_error(test_y,y_pred)))
# Out:
# MAE : 3.445897483800309e-07
# MSE : 1.5012617947943056e-13
# RMSE : 3.8746119738553245e-07

# %% [markdown]
# ## Residuals
#
# You should have gotten a very good model with a good fit. Let's quickly explore the residuals to make sure everything was okay with our data.
#
# **Plot a histogram of the residuals and make sure it looks normally distributed. Use either seaborn distplot, or just plt.hist().**
#
# >  here actual - pred will give residul plot in histogram of the residuals and make sure it looks normally distributed
# #In this case its almost normally distrbuted
#    > One of the condition in linear regression.
#   > 5.Normality:For any value of X, Y(O/P) is normally distributed. The residuals of the model are normally distributed.

# %%
#Residual distplot
sns.distplot((test_y-y_pred),bins=5)
# here actual - pred will give residul plot in histogram of the residuals and make sure it should looks normally distributed
# One of the condition in linear regression. 
# 5.Normality:For any value of X, Y(O/P) is normally distributed. The residuals of the model are normally distributed.
# Out:
# C:\Users\prabh\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### In this scenario we are  predicting  rating of a cerel.
# > If ay new cerels comes, based on its sugur, vitamin, other content basis we can predict users rating based on existing data and its rating
#
# > Here Rating is the output column, Other fields are the input column
#
# > We have choosen linear model beacuse its a continous data and checked its score(Which is high) and RMSE(Which is low)
#
# > So looks like model is good
