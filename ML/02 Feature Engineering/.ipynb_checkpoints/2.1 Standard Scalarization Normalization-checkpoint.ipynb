# %% [markdown]
# ## 1. Standardization : Ex: StandardScaler
# - These are slightly different operations. Standardization refers to scaling a set of values so that they have a mean of zero and a standard deviation of one.
#
# - Here we are standardizing and transforming the data in such a way that the mean of the transformed data is 0 and the Variance is 1
#
# - The fit() method is used to compute the mean and std dev which will be used for later scaling. This method computes it separately for each feature in a dataset.
#
# - We apply scalar first on full set and then do train test split
#
# - Next Transform method is used to perform Standardization by centering and Scaling.
#
# - So fit_transform() method can be used on Train set for computing the mean and std for each feature and then transform() can be later used on with the Test data set.

# %%
# Since the Feature Scaling methods works on numerical columns its better to extract the numerical columns
# create another DF, apply the scaling, then copy it back to main dataframe.  

#Since the main aim is all features have to be at the same level of scale or magnitude, all numerical columns 
#should be scaled together. 

#Some columns may be defined as numerical (i.e int or float) but the value inside it may be like categorical 
#(Eg: pclass below), no need to select these type of columns for feature scaling. 

#Some columns may be defined as categorical (i.e object ) but the value inside it is numerical
#(Eg: age, fare below),so need to convert them into numerical and select these type of columns for scaling.

#Some columns may hold unqiue numbers/running numbers/Identification numbers, those we can 
# skip (eg: boat, body below)

# Target column should be excluded from the scaling. 

# In below data set not sure whether to select sibsp,parch for scaling or not, since it says about number of
#siblings and number of parents, but have selected for now. 

# You have to remember that the choice of the algorithm for your project impacts 
# whether you need scale your variables or not. 

#Scaling is easy to understand and should be verified using visualization.
#Now since i'm not well versed in coding have not added the visualization.
#In future once comfortable with plotting, need to add before scaling and after scaling plotting for all of the 
#below methods. That helps to understand very better.

'''
Algorithms sensitive to feature magnitude:

Linear and logistic regression
Neural networks
Support vector machines
KNN
K-means clustering
Linear discriminant analysis (LDA)
Principal component analysis (PCA)


Algorithms intensive to feature magnitude:

Classification and regression trees
Random forests
Gradient boosted trees
'''
# Out:
# '\nAlgorithms sensitive to feature magnitude:\n\nLinear and logistic regression\nNeural networks\nSupport vector machines\nKNN\nK-means clustering\nLinear discriminant analysis (LDA)\nPrincipal component analysis (PCA)\n\n\nAlgorithms intensive to feature magnitude:\n\nClassification and regression trees\nRandom forests\nGradient boosted trees\n'

# %% [markdown]
# ## Create a 2D matrix with random integers with range [-1,3]

# %%
from sklearn.preprocessing import StandardScaler,scale
import sklearn.preprocessing
import numpy as np
X_train = np.random.randint(-1,3, size=(3, 3))
X_train
# Out:
# array([[ 2,  1, -1],
#        [ 1, -1,  1],
#        [ 0,  1, -1]])

# %% [markdown]
# ### Create an Object of StandardScaler

# %%
scaler = StandardScaler()

StandardScaler(copy=True, with_mean=True, with_std=True)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# - We will use fit() function to compute the mean, variance and std dev of the X_train along axis = 0 (Column wise/field wise)

# %%
scaler.fit(X_train)
print('  mean: ',scaler.mean_,'n','variance: ',scaler.var_)
# Out:
#   mean:  [1.         0.33333333 0.66666667] n variance:  [2.         0.88888889 0.22222222]

# %% [markdown]
# - Now transform the X-train data to remove the mean and scale Variance to 1 (Now data looks like column wise mean =0 (Mean : sum all value in col and divide by 3 =0)

# %%
scaler.transform(X_train)
# Out:
# array([[ 0.70710678,  0.70710678,  0.70710678],
#        [ 0.70710678,  0.70710678,  0.70710678],
#        [-1.41421356, -1.41421356, -1.41421356]])

# %% [markdown]
# > This is finally the transformed data using the Standardscaler with mean Zero and Standard Deviation and Variance of 1

# %% [markdown]
#  - Let’s use the preprocessing scale() function to transform the same dataset and see if it gives the same result or not

# %%
X_transformed = scale(X_train)
X_transformed
# Out:
# array([[ 1.22474487,  0.70710678, -0.70710678],
#        [ 0.        , -1.41421356,  1.41421356],
#        [-1.22474487,  0.70710678, -0.70710678]])

# %%
print(' Mean:  ',X_transformed.mean(axis=0),'n','Stdev: ',X_transformed.std(axis=0))
# Out:
#  Mean:   [ 0.00000000e+00  7.40148683e-17 -7.40148683e-17] n Stdev:  [1. 1. 1.]

# %% [markdown]
# > The mean and Stdev along axis = 0 is zero and one respectively so the data is standardized appropriately
#
# > Let’s try the same scaler on a New dataset

# %%
X_test = np.random.randint(-1,3, size=(2,3))
X_test
# Out:
# array([[ 1, -1,  1],
#        [-1,  1,  1]])

# %% [markdown]
# - Now use the same scaler instance as above and transform this new or test dataset the same way as it did it for X_train

# %%
scaler.transform(X_test)
# Out:
# C:\Users\prabh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.        , -0.70710678,  0.        ],
#        [-2.44948974,  1.41421356,  0.        ]])

# %% [markdown]
# ## 2. Normalization : - MinMax Scaler
#
# - Normalization:
#
# - Normalization refers to scaling a set of values so that the range if between zero and one.
#
# ##### Normalization: MinMax Scaler
#
# - It standardize the data by transforming within a given range. Moreover the Feature scaling lies between a minimum and maximum value so that the maximum absolute value of each feature is scaled to unit size
#
# -  Minmaxscaler also scales each of the feature individually for example between 0 and 1. This is good scaling options when you want to preserve the zero’s in a sparse dataset

# %% [markdown]
# Following formula is used for the transformation
#
# X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
# X_scaled = X_std * (max - min) + min

# %%
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 3))
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_train_minmax
# Out:
# C:\Users\prabh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[3. , 0. , 0. ],
#        [1.5, 3. , 0. ],
#        [0. , 0. , 0. ]])

# %% [markdown]
# - We can use the same instance of min_max_Scaler on the X_test dataset created above

# %%
X_test_minmax = min_max_scaler.transform(X_test)
X_test_minmax
# Out:
# array([[ 1.5,  0. ,  0. ],
#        [-1.5,  3. ,  0. ]])

# %% [markdown]
# Use scale_ attribute to check the min_max_scaler attributes to determine the exact nature of the transformation learned on the training data
#
# The scale_ attribute is Per feature relative scaling of the data. Equivalent to (max - min) / (X.max(axis=0) - X.min(axis=0))

# %% [markdown]
# - Let’s check the scale_ attributes that is learnt for our example

# %%
min_max_scaler.scale_
#There is another function min_max_scale which is an equivalent function without the estimator API
# Out:
# array([1.5, 1.5, 3. ])

# %% [markdown]
# ## 3. Same test with real dataset :
#
# ### Real World Dataset
#
#  - Let’s work on real dataset and check how standard and min_max scaling works on features of sklearn wine dataset

# %%
from sklearn.datasets import load_wine
windata = load_wine()

# %%
windata.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# - We will consider only features alcalinity_of_ash and magnesium for scaling and standardization since there are outliers available in these features

# %%
from sklearn.preprocessing import MinMaxScaler
minmax_scale = preprocessing.MinMaxScaler(feature_range=(0, 1))


X = windata.data[:,[3,4]]
y = windata.target

# scale the output between 0 and 1 for the colorbar
y = minmax_scale(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-36676495e909> in <module>
#       7
#       8 # scale the output between 0 and 1 for the colorbar
# ----> 9 y = minmax_scale(y)
#
# TypeError: 'MinMaxScaler' object is not callable

# %% [markdown]
# ##### Let’s do a StandardScaler transform of the features

# %%
X_transform = StandardScaler().fit_transform(X)

# %% [markdown]
# > We will plot the data with their target data(Y) as colormaps in a 2D axis
#
# Additionally Standard scalar removes the mean therefore the spread of transformed data for each feature is different. Transformed alcalinity_of_ash has a range of [-2,3] whereas transformed magnesium is squeezed in [-2,4]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %% [markdown]
# ### The scatter plot

# %%
fig, (ax1,ax2) = plt.subplots(1, 2,figsize=(20,6))
#colors = cmap(y)

ax1.scatter(X[:, 0], X[:, 1], alpha=0.5, marker='o', s=10, lw=2)#, c=colors)
ax2.scatter(X_transform[:, 0], X_transform[:, 1], alpha=0.5, marker='o', s=10, lw=2 )#, c=colors)

ax1.set_title("Before Scaling")
ax2.set_title("After Scaling")
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %% [markdown]
# ## Mean Normalization - Scaling

# %%
# Mean normalization suggests centering the variable at 0 and 
# re-scaling the variable’s value range to the range of -1 to 1.
'''
Here’s what you need to remember about mean normalization:

It centers the mean at 0.
The resulting variance will be different.
It may modify the shape of the original distribution.
It “normalizes” the minimum and maximum values within the range[-1, 1].
It preserves outliers if they exist.
'''
# Out:
# '\nHere’s what you need to remember about mean normalization:\n\nIt centers the mean at 0.\nThe resulting variance will be different.\nIt may modify the shape of the original distribution.\nIt “normalizes” the minimum and maximum values within the range[-1, 1].\nIt preserves outliers if they exist.\n'

# %% [markdown]
# ## Min-Max Scaling - Normalization

# %%
# Minimum and maximum scaling both compress the values between 0 and 1. 

'''
Here’s what you need to remember about Min-Max Scaling:

It does not center the mean at 0.
It makes the variance vary across variables.
It may not maintain the shape of the original distribution.
The minimum and maximum values are in the range of [0,1].
This method is very sensitive to outliers.

'''
# Out:
# '\nHere’s what you need to remember about Min-Max Scaling:\n\nIt does not center the mean at 0.\nIt makes the variance vary across variables.\nIt may not maintain the shape of the original distribution.\nThe minimum and maximum values are in the range of [0,1].\nThis method is very sensitive to outliers.\n\n'

# %% [markdown]
# ## Standardization - Standard Scaler

# %%
# Standardization suggests centering the variable at 0 and standardizing the variance to 1. 

# please note here, its standardizing the variance to 1, not that values will be restricted within 1.

'''
Here’s what you need to remember about standardization:

It scales the variance at 1.
It centers the mean at 0.
It preserves the shape of the original distribution.
It preserves outliers if they exist.
Minimum and maximum values vary.

'''

# %% [markdown]
# ## Robust Scaling (scaling to median and IQR)¶

# %%
#In this method, the median is used instead of the mean. 
#We remove the median from the variable observations, and then we scale to the inter-quantile range (IQR).

'''
Here’s what you need to remember about robust scaling:

It centers the median at 0 .
The resulted variance varies across variables.
It may not preserve the shape of the original distribution.
The minimum and maximum values vary.
It is robust to outliers.

'''
# Out:
# '\nHere’s what you need to remember about robust scaling:\n\nIt centers the median at 0 .\nThe resulted variance varies across variables.\nIt may not preserve the shape of the original distribution.\nThe minimum and maximum values vary.\nIt is robust to outliers.\n\n'

# %% [markdown]
# ## Maximum Absolute Scaling

# %%
## Maximum absolute scaling scales the variable values between -1 and 1 by dividing the data by its maximum value

'''
Here is what you need to remember about Maximum Absolute Scaling:

The resulting mean is not centered.
It doesn't scale the variance.
It’s sensitive to outliers.

'''
# Out:
# "\nHere is what you need to remember about Maximum Absolute Scaling:\n\nThe resulting mean is not centered.\nIt doesn't scale the variance.\nIt’s sensitive to outliers.\n\n"

# %% [markdown]
# ## Scaling to vector unit norm

# %%
'''
Here’s what you need to remember about scaling to the vector unit norm:

The length of the resulting vector is 1.
It normalizes the feature vector and not the observation vector.
It’s sensitive to outliers.
Recommended for text classification and clustering.
'''
# Out:
# '\nHere’s what you need to remember about scaling to the vector unit norm:\n\nThe length of the resulting vector is 1.\nIt normalizes the feature vector and not the observation vector.\nIt’s sensitive to outliers.\nRecommended for text classification and clustering.\n'

# %% [markdown]
# ###  All above types example explained by wastu in his FE DSH_FE10_FeatureScaling.ipynb Doc
