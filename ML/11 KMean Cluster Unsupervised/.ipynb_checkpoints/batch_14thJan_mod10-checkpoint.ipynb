# %% [markdown]
# # k-Means

# %%
"""
Problem:

And eventually after collecting this data set the company hired you as
a machine earning scientist to segment their clients in 
different groups based on these two metrics, 'the annual income' and
'the spending score' and since the mall has no idea of what 
this client segments might be or even has no idea about how many segments there would be.

"""
# Out:
# "\nProblem:\n\nAnd eventually after collecting this data set the company hired you as\na machine earning scientist to segment their clients in \ndifferent groups based on these two metrics, 'the annual income' and\n'the spending score' and since the mall has no idea of what \nthis client segments might be or even has no idea about how many segments there would be.\n\n"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# data set
dataset = pd.read_csv('mall_data.csv')
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# input data
X = dataset.iloc[:,[3,4]].values
#X = dataset[['Annual Income (k$)','Spending Score (1-100)']].values
X[:5]
# Out:
# array([[15, 39],
#        [15, 81],
#        [16,  6],
#        [16, 77],
#        [17, 40]], dtype=int64)

# %%
# using elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans

wcss = []  # within cluster square of sums or inertia

for i in range(1,11):
    #n_init:default=10 It is the no. of times the KMeans algorithm will be run with different initial centroid.
    kmeans_model = KMeans(n_clusters=i, init='k-means++',  max_iter=300,
                         n_init=10, random_state=42)
    #train the model
    kmeans_model.fit(X)
    wcss.append(kmeans_model.inertia_)

plt.plot(range(1,11), wcss)
plt.title("Elbow method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
# so the appropriate value for k is 5

# %%
kmean = KMeans(n_clusters=5, init='k-means++')
y_means = kmean.fit_predict(X)
y_means  # cluster IDs from 0 to 4
#y_means : cluster numbers which input data belongs to
# Out:
# array([4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1,
#        4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 2,
#        4, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 0, 3, 2, 3, 0, 3, 0, 3,
#        2, 3, 0, 3, 0, 3, 0, 3, 0, 3, 2, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3,
#        0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3,
#        0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3,
#        0, 3])

# %%
# visulizing the clusters
#Here X[y_means == 0, 0], X[y_means == 0, 1]   this part will gives X and Y axis values . both values are there in variable X
#X[y_means == 0, 0] if y_means == 0 means y_means is 1st cluster then take X[0] value as x axis point with cluster color 'red', label='Cluster 1'
#X[y_means == 0, 1] if y_means == 0 means y_means is 1st cluster then take X[1] value as y axis point with cluster color 'red', label='Cluster 1'
#X[0] --> Annual Income (k$) ,   X[1] --> Spending Score (1-100)

"""
Explaining visualization code
In general: plt.scatter(X_axis_data, Y_axis_data, ....)
In our code: X contains input data (X_axis_data, Y_axis_data) and y_means contains output i.e cluster ids(0 to 4)
X[y_kmeans == 0, 0] -> first '0' means the cluster id 0, second 0 is first column of X,it would return X co-ordinates for cluster 0
X[y_kmeans == 0, 1] -> '0' means the cluster id 0, 1 is second column of X that is y-axis for scatter method

s = 100 is the size

Cluster 1: careful
Cluster 2: Standard
Cluster 3: Target
Cluster 4: careless
Cluster 5: sensible
"""

plt.scatter(X[y_means == 0, 0], X[y_means == 0, 1],
           s=100, c='red', label='Cluster 1')
plt.scatter(X[y_means == 1, 0], X[y_means == 1, 1],
           s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_means == 2, 0], X[y_means == 2, 1],
           s=100, c='green', label='Cluster 3')
plt.scatter(X[y_means == 3, 0], X[y_means == 3, 1],
           s=100, c='cyan', label='Cluster 4')
plt.scatter(X[y_means == 4, 0], X[y_means == 4, 1],
           s=100, c='magenta', label='Cluster 5')
plt.scatter(kmean.cluster_centers_[:,0], kmean.cluster_centers_[:,1],
            s=300, c='yellow', label='Centroids')
plt.title("Cluster of customers")
plt.xlabel("Annual Income")
plt.ylabel("Spending score")
plt.legend()
plt.show()

# %%
kmean.cluster_centers_  # centroid positions
# Out:
# array([[88.2       , 17.11428571],
#        [25.72727273, 79.36363636],
#        [55.2962963 , 49.51851852],
#        [86.53846154, 82.12820513],
#        [26.30434783, 20.91304348]])
