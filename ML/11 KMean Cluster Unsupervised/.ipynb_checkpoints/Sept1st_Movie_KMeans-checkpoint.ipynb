# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the data
data = pd.read_csv('movie_metadata1.csv')
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                     723       178
# 1  Color     Gore Verbinski                     302       169
# 2  Color         Sam Mendes                     602       148
# 3  Color  Christopher Nolan                     813       164
# 4     49        Doug Walker                      49        49
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0                     855  Joel David Moore
# 1                      563                    1000     Orlando Bloom
# 2                        0                     161      Rory Kinnear
# 3                    22000                   23000    Christian Bale
# 4                      131                      49        Rob Walker
#
#    actor_1_facebook_likes      gross                           genres  \
# 0                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
# get the relevant columns from the inout dataset
f1 = data['director_facebook_likes'].values
f2 = data['actor_3_facebook_likes'].values

X = np.array(list(zip(f1,f2)))
X
plt.scatter(f1, f2,c='black', s=50)
plt.xlabel('director_facebook_likes')
plt.ylabel('actor_3_facebook_likes')
# Out:
# Text(0,0.5,'actor_3_facebook_likes')

# %%
k = 5

# %%
def dist(a,b,ax=1):
    return np.linalg.norm(a-b,axis=ax)
k = 5

# 1: random centroids
C_x = np.random.randint(0, np.max(X)-20, size=k)
C_y = np.random.randint(0, np.max(X)-20, size=k)

# random centroids
C = np.array(list(zip(C_x, C_y)),dtype=np.float32)
C
# Out:
# array([[ 9177., 16806.],
#        [ 1527., 17964.],
#        [14854., 21990.],
#        [15734., 10351.],
#        [11857., 22483.]], dtype=float32)

# %%
# plotting the data points with random centroids
plt.scatter(f1, f2, s=10)
plt.scatter(C_x, C_y, marker='*', s=200,c='g')
plt.xlabel('director_facebook_likes')
plt.ylabel('actor_3_facebook_likes')
# Out:
# Text(0,0.5,'actor_3_facebook_likes')
